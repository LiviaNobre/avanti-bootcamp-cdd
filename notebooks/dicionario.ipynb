# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/atlantico-academy/datasets/main/titanic.csv')
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.to_csv("../data/raw/titanic.csv", index=False)

# %%
dicionario = pd.DataFrame([
    {
        "variavel": "survived",
        "descricao": "Binário indicando se o passageiro sobreviveu ou não",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },{
        "variavel": "pclass",
        "descricao": "Tipo de classe da passagem - representa também a classe social do pasageiro",
        "tipo":"qualitativa",
        "subtipo":"ordinal"
    },{
        "variavel": "sex",
        "descricao": "Sexo dos passageiros",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "age",
        "descricao": "Idade",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel": "sibsp",
        "descricao": "Quantidade de irmãos, meio-irmãos, marido e mulher",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel": "parch",
        "descricao": "Quantidade de filhos e enteados, pai ou mãe",
        "tipo":"quantitativa",
        "subtipo":"discreta"
    },{
        "variavel": "fare",
        "descricao": "Valor da passagem",
        "tipo":"quantitativa",
        "subtipo":"continua"
    },{
        "variavel": "embarked",
        "descricao": "Portão de embarque",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "class",
        "descricao": "Classe",
        "tipo":"qualitativa",
        "subtipo":"ordinal"
    },{
        "variavel": "who",
        "descricao": "Categoriza o passageiro em homem, mulher e criança",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "adult_male",
        "descricao": "Indicador se o passageiro é um homem adulto",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "deck",
        "descricao": "Sessão do navio",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "embark_town",
        "descricao": "Cidade de embarque",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "alive",
        "descricao": "Coluna indicando se o passageiro está vivo",
        "tipo":"qualitativa",
        "subtipo":"nominal"
    },{
        "variavel": "alone",
        "descricao": "Coluna indicando se o passageiro está sozinho no navio",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    }
])
    
dicionario.to_csv("../data/external/dictionary.csv", index=False)
dicionario
# Out:
#        variavel                                          descricao  \
# 0      survived  Binário indicando se o passageiro sobreviveu o...
# 1        pclass  Tipo de classe da passagem - representa também...
# 2           sex                               Sexo dos passageiros
# 3           age                                              Idade
# 4         sibsp  Quantidade de irmãos, meio-irmãos, marido e mu...
# 5         parch        Quantidade de filhos e enteados, pai ou mãe
# 6          fare                                  Valor da passagem
# 7      embarked                                 Portão de embarque
# 8         class                                             Classe
# 9           who  Categoriza o passageiro em homem, mulher e cri...
# 10   adult_male        Indicador se o passageiro é um homem adulto
# 11         deck                                    Sessão do navio
# 12  embark_town                                 Cidade de embarque
# ...
